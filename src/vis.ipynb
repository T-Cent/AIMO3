# %%
import pandas as pd

data = pd.read_parquet("silver_annotations_gptoss-20b.parquet")

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   problem       83 non-null     object
#  1   solution      83 non-null     object
#  2   hints         83 non-null     object
#  3   facts         83 non-null     object
#  4   verification  83 non-null     object
#  5   answer        83 non-null     object
#  6   tags          83 non-null     object
#  7   is_correct    83 non-null     bool
#  8   raw_output    83 non-null     object
#  9   source        83 non-null     object
#  10  annotator     83 non-null     object
# dtypes: bool(1), object(10)
# memory usage: 6.7+ KB
